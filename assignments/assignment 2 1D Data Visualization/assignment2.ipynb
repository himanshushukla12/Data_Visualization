# %%
import pandas as pd

# %%
# Reading only the Gender and Height columns from the Excel file
file_path = '200 participant collected data.xlsx'

# Reading the Excel file to inspect column names
df_preview = pd.read_excel(file_path, nrows=5)
df_preview.columns.tolist()
# Out:
# ['Participant Number',
#  'Gender',
#  'Age',
#  'Dominant Hand',
#  'Height (cm) (average of 3 measurments)',
#  'Weight (kg) (average of 3 measurements)',
#  'Fingertip Temperature (°C)',
#  'Fingerprint Height (mm)',
#  'Fingerprint Width (mm)',
#  'Fingerprint Area (mm2)',
#  'Fingerprint Circumference (mm)']

# %%
df["Gender"] = df["Gender"].str.capitalize()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Height (cm) (average of 3 measurments)", hue="Gender", element="step", stat="density", common_norm=False)
plt.title("Distribution of Heights by Gender")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Gender", y="Height (cm) (average of 3 measurments)", palette="pastel")
plt.title("Box Plot of Heights by Gender")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="Gender", y="Height (cm) (average of 3 measurments)", palette="pastel", inner="quartiles")
plt.title("Violin Plot of Heights by Gender")
plt.show()
